# %%
#Dependcies
import pandas as pd
pd.__version__
import numpy as np

# %%
#Trend Observations:
#1. Purchases in the age range of 15 through 29 skyrocket,
# totaling into the hundreds, in comparison to other ages.  
# With this in mind, we can drive number of purchases even
# higher by targeting this group with promotional releases.
#2. The price point of around $2 has the most frequent purchases
# we should examine more into the cause of this (could it be
# members find this most affordable, or is the in-game
# equipment in this range most poplular for asthetics,
# combat, etc.)
#3. Many members have multiple accounts.  This might help when
# publishing popularity numbers, but harder to track for 
# patters in playing, purchasing, communicating wwith others.
# We need promotions that don't incentivise having multiple
# accounts.  Example, having sign-up bonuses for new players,
# but nothing for current, will encourage this behavior.  Let's
# tailor events like these for both types of players to increase
# new members, but also decrease players remaking accounts.

# %%
#call json file on schools
#create DataFrame
#use .head() to check
json_1_path = "Resources/purchase_data.json"
json_2_path = "Resources/purchase_data2.json"
file_1_DF = pd.read_json(json_1_path)
file_1_DF.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
#create DataFrame for 2nd file
file_2_DF = pd.read_json(json_2_path)
file_2_DF.head()
# Out:
#    Age Gender  Item ID                 Item Name  Price          SN
# 0   20   Male       93  Apocalyptic Battlescythe   4.49     Iloni35
# 1   21   Male       12                     Dawne   3.36   Aidaira26
# 2   17   Male        5                Putrid Fan   2.63      Irim47
# 3   17   Male      123         Twilight's Carver   2.55     Irith83
# 4   22   Male      154              Feral Katana   4.11  Philodil43

# %%
#Convert series into DataFrams
Finished_Table = pd.DataFrame({"Player Count": player_counts,
                           "Number of Unique Items": unique_purchases,
                           "Average Purchase Price": price_mean,
                           "Total Number of Purchases": purchase_count_1,
                           "Total Revenue": totalRevenue,
                           "Count of Male Players": male_players_1,
                           "Percent of Male Players": male_percentage_1 * 100,
                           "Count of Female Players": female_players_1,
                           "Percent of Female Players": female_percentage_1 * 100,
                           "Count of Other / Non-Disclosed": other_players_1,
                           "Percent of Other / Non-Disclosed": other_percentage_1 * 100},
                            
                           index = [0])


player_count.index.names=["Finished Table"]
Finished_Table
# Out:
#    Average Purchase Price  Count of Female Players  Count of Male Players  \
# 0                2.931192                      100                    465
#
#    Count of Other / Non-Disclosed  Number of Unique Items  \
# 0                               8                     152
#
#   Percent of Female Players Percent of Male Players  \
# 0                        17                      81
#
#   Percent of Other / Non-Disclosed  Player Count  Total Number of Purchases  \
# 0                                1           573                        780
#
#    Total Revenue
# 0        2286.33

# %%
purchaseAnalysis= pd.DataFrame({"Number of Unique Items": unique_purchases,
                           "Average Purchase Price": price_mean,
                           "Total Number of Purchases": purchase_count_1,
                           "Total Revenue": totalRevenue},
                          index = [0])
purchaseAnalysis.index.names=["Purchase Analysis Totals"]
purchaseAnalysis
# Out:
#                           Average Purchase Price  Number of Unique Items  \
# Purchase Analysis Totals
# 0                                       2.931192                     152
#
#                           Total Number of Purchases  Total Revenue
# Purchase Analysis Totals
# 0                                               780        2286.33

# %%
genderDemo= pd.DataFrame({"Count of Male Players": male_players_1,
                           "Percent of Male Players": male_percentage_1 * 100,
                           "Count of Female Players": female_players_1,
                           "Percent of Female Players": female_percentage_1 * 100,
                           "Count of Other / Non-Disclosed": other_players_1,
                           "Percent of Other / Non-Disclosed": other_percentage_1 * 100},
        
                          index = [0])
genderDemo
# Out:
#    Count of Female Players  Count of Male Players  \
# 0                      100                    465
#
#    Count of Other / Non-Disclosed Percent of Female Players  \
# 0                               8                        17
#
#   Percent of Male Players Percent of Other / Non-Disclosed
# 0                      81                                1

# %%
gender_finished
# Out:
#                        Total Purchase Value      sum  count     0     1
# Female                               382.91   382.91    136  2.82  3.83
# Male                                1867.68  1867.68    633  2.95  4.02
# Other / Non-Disclosed                 35.74    35.74     11  3.25  4.47

# %%
ageAnalysis= pd.DataFrame({"Purchase Count": ageCount,
                          "Average Purchase Price": ageAvgPp,
                          "Total Purchase Value": ageTotalPV,
                          "Normalized Total": ageNormTotals})
ageAnalysis
# Out:
#                   Average Purchase Price  Normalized Total  Purchase Count  \
# Age Demographics
# <10                                 2.98              2.98              28
# 10-14                               2.77              2.77              35
# 15-19                               2.91              2.91             133
# 20-24                               2.91              2.91             336
# 25-29                               2.96              2.96             125
# 30-34                               3.08              3.08              64
# 35-39                               2.84              2.84              42
# 40+                                 3.16              3.16              17
#
#                   Total Purchase Value
# Age Demographics
# <10                              83.46
# 10-14                            96.95
# 15-19                           386.42
# 20-24                           978.77
# 25-29                           370.33
# ...

# %%
topSpenders.nlargest(5, "Total Purchase Value")
# Out:
#                 0  Total Purchase Value  Purchase Count
# Undirrala66  3.41                 17.06               5
# Saedue76     3.39                 13.56               4
# Mindimnya67  3.18                 12.74               4
# Haellysu29   4.24                 12.73               3
# Eoda93       3.86                 11.58               3

# %%
mostPopularTable.sort_values("Purchase Count", ascending=False).head()
# Out:
#                                                  0  Total Purchase Value  \
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows  2.35                 25.85
# 84      Arcane Gem                            2.23                 24.53
# 31      Trickster                             2.07                 18.63
# 175     Woeful Adamantite Claymore            1.24                 11.16
# 13      Serenity                              1.49                 13.41
#
#                                               Purchase Count
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows              11
# 84      Arcane Gem                                        11
# 31      Trickster                                          9
# 175     Woeful Adamantite Claymore                         9
# 13      Serenity                                           9

# %%
mostProfitItemPriced.nlargest(5, "Total Purchase Value")
# Out:
#                                        0  Purchase Count  Total Purchase Value
# Item ID Item Name
# 34      Retribution Axe             4.14               9                 37.26
# 115     Spectral Diamond Doomblade  4.25               7                 29.75
# 32      Orenmir                     4.95               6                 29.70
# 103     Singed Scalpel              4.87               6                 29.22
# 107     Splitter, Foe Of Subtlety   3.61               8                 28.88

# %%
file_1_DF["Item ID"].unique()
file_1_DF["Item ID"].value_counts()
# Out:
# 84     11
# 39     11
# 31      9
# 34      9
# 175     9
# 13      9
# 106     8
# 44      8
# 92      8
# 65      8
# 152     8
# 107     8
# 172     7
# 179     7
# 115     7
# 154     7
# 79      7
# 158     7
# 108     7
# 66      7
# 11      7
# 130     7
# 18      7
# 124     6
# 103     6
# 101     6
# 121     6
# 102     6
# 73      6
# 145     6
#        ..
# 116     2
# 89      2
# 64      2
# 9       2
# 167     2
# 80      2
# 74      2
# 72      2
# 146     2
# 149     2
# 150     2
# 178     2
# 62      2
# 58      2
# 56      2
# 55      2
# 4       1
# 2       1
# 3       1
# 59      1
# 28      1
# 168     1
# 164     1
# 43      1
# 156     1
# 147     1
# 136     1
# 126     1
# 109     1
# 0       1
# Name: Item ID, Length: 183, dtype: int64

# %%
unique_purchases = len(file_1_DF["Price"].unique())
unique_purchases
# Out:
# 152

# %%
price_mean = file_1_DF["Price"].mean()
price_mean
# Out:
# 2.931192307692303

# %%
purchase_count_1 = len(file_1_DF["Price"])
purchase_count_1
# Out:
# 780

# %%
player_counts = len(file_1_DF["SN"].value_counts())
player_counts
# Out:
# 573

# %%
#create a unique listing for each file
player_counts_2 = len(file_2_DF["SN"].value_counts())
player_counts_2
# Out:
# 74

# %%
totalRevenue = sum(file_1_DF["Price"])
totalRevenue
# Out:
# 2286.3299999999963

# %%
player_count = pd.DataFrame({"Player Count": player_counts},
                           index = [0])


player_count.index.names=["Total Number of Players"]
player_count
# Out:
#                          Player Count
# Total Number of Players
# 0                                 573

# %%
#Convert series into DataFrams
purchaseAnalysis= pd.DataFrame({"Number of Unique Items": unique_purchases,
                           "Average Purchase Price": price_mean,
                           "Total Number of Purchases": purchase_count_1,
                           "Total Revenue": totalRevenue},
                          index = [0])
purchaseAnalysis.index.names=["Purchase Analysis Totals"]
purchaseAnalysis
# Out:
#                           Average Purchase Price  Number of Unique Items  \
# Purchase Analysis Totals
# 0                                       2.931192                     152
#
#                           Total Number of Purchases  Total Revenue
# Purchase Analysis Totals
# 0                                               780        2286.33

# %%
#Gender Demographics
#Percentage and Counts of Male/Female Players
#Percentage and Counts of Other/Non-Disclosed
male_count_1 = file_1_DF.groupby(["SN", "Gender"])
male_count_1.count().head()
# Out:
#                      Age  Item ID  Item Name  Price
# SN           Gender
# Adairialis76 Male      1        1          1      1
# Aduephos78   Male      3        3          3      3
# Aeduera68    Male      3        3          3      3
# Aela49       Male      1        1          1      1
# Aela59       Male      1        1          1      1

# %%
players_1 = len(file_1_DF.loc[file_1_DF["Gender"] == "Male"])
players_1
# Out:
# 633

# %%
male_players_1 = len(male_count_1)
male_players_1
#mp1 = file_1_DF["Gender"].value_counts()["Male"]
#mp1
# Out:
# 573

# %%
male_percentage_1 = male_players_1 / purchase_count_1
male_percentage_1 * 100
# Out:
# 73.46153846153847

# %%
female_players_1 = len(file_1_DF.loc[file_1_DF["Gender"] == "Female"])
female_players_1
# Out:
# 136

# %%
female_percentage_1 = female_players_1 / purchase_count_1
female_percentage_1 * 100
# Out:
# 17.435897435897434

# %%
other_players_1 = len(file_1_DF.loc[file_1_DF["Gender"] == "Other / Non-Disclosed"])
other_players_1
# Out:
# 11

# %%
other_percentage_1 = other_players_1 / purchase_count_1
other_percentage_1 * 100
# Out:
# 1.4102564102564104

# %%
#Gender Demographics
#Percentage and Counts of Male/Female Players
#Percentage and Counts of Other/Non-Disclosed
male_count_1 = file_1_DF.groupby(["SN", "Gender"]).size()
#Convert series into DataFrames
players_1 = pd.DataFrame(male_count_1)
players_1
players_2 = pd.DataFrame(players_1.groupby(["Gender"]).count())
players_2.columns = ["Count"]
players_2
# Out:
#                        Count
# Gender
# Female                   100
# Male                     465
# Other / Non-Disclosed      8

# %%
male_players_1 = players_2["Count"].loc["Male"]
print(male_players_1)
male_percentage_1 = round(male_players_1 / player_count, 2)
male_percentage_1 * 100
female_players_1 = players_2["Count"].loc["Female"]
female_players_1
female_percentage_1 = round(female_players_1 / player_count, 2)
female_percentage_1 * 100
other_players_1 = players_2["Count"].loc["Other / Non-Disclosed"]
other_percentage_1 = round(other_players_1 / player_count, 2)
other_percentage_1 * 100
genderDemo= pd.DataFrame({"Count of Male Players": male_players_1,
                           "Percent of Male Players": male_percentage_1 * 100,
                           "Count of Female Players": female_players_1,
                           "Percent of Female Players": female_percentage_1 * 100,
                           "Count of Other / Non-Disclosed": other_players_1,
                           "Percent of Other / Non-Disclosed": other_percentage_1 * 100},
        
                          index = [0])
genderDemo
# Out:
# 465
#    Count of Female Players  Count of Male Players  \
# 0                      100                    465
#
#    Count of Other / Non-Disclosed Percent of Female Players  \
# 0                               8                        17
#
#   Percent of Male Players Percent of Other / Non-Disclosed
# 0                      81                                1

# %%
#Puchase Analysis (Gender)
#Purchase Count
purchase_countGender = file_1_DF.groupby(["Gender"]).count()
purchase_countGender.head()
purchase_countGender.rename(columns={"Age": "Count"}, inplace=True)
purchase_countGender.drop(purchase_countGender.columns[[1,2,3,4,5]], axis=1, inplace=True)
purchase_countGender
genderCount=purchase_countGender
genderCount
#Rename 1st column and drop remaining columns
# Out:
#                        Count
# Gender
# Female                   136
# Male                     633
# Other / Non-Disclosed     11

# %%
#Gender Purchasing Analysis
genderData = file_1_DF.groupby(["Gender"]).sum()
genderData.drop(genderData.columns[[0,1]], axis=1, inplace=True)
genderData.rename(columns={"Price": "Total Purchase Value"}, inplace=True)
print(genderData.sort_values("Total Purchase Value", ascending=False))
#Purchase Count
genderPurchaseCount= file_1_DF.groupby("Gender")["Price"].agg(["sum","count"])
gPC = genderPurchaseCount.sort_values("count", ascending= False)
print(gPC.nlargest(5, "count").head())

avgPrice = round(gPC["sum"].div(gPC["count"]),2)
print(avgPrice)

normPrice= round(gPC["sum"].div(players_2["Count"]),2)
print(normPrice)
gender_finished = pd.concat([genderData, gPC, avgPrice, normPrice], axis=1)
gender_finished.rename(columns={"0": "Average Purchase Price", "1": "Normalized Totals"}, inplace=True)
gender_finished
#Remove Age
#Remove Item ID
#For Normalized Divide by number of people in each gender
# genderAnalysis = pd.DataFrame({"Purchase Count by Gender":gPC,
#                                "Average Purchase Price": avgPrice,
#                                "Total Purchase Value": genderData,
#                                "Normalized Purchase Price": normPrice
    
# })
# genderAnalysis
# Out:
#                        Total Purchase Value
# Gender
# Male                                1867.68
# Female                               382.91
# Other / Non-Disclosed                 35.74
#                            sum  count
# Gender
# Male                   1867.68    633
# Female                  382.91    136
# Other / Non-Disclosed    35.74     11
# Gender
# Male                     2.95
# Female                   2.82
# Other / Non-Disclosed    3.25
# dtype: float64
# Gender
# Female                   3.83
# Male                     4.02
# Other / Non-Disclosed    4.47
# dtype: float64
#                        Total Purchase Value      sum  count     0     1
# Female                               382.91   382.91    136  2.82  3.83
# Male                                1867.68  1867.68    633  2.95  4.02
# Other / Non-Disclosed                 35.74    35.74     11  3.25  4.47

# %%
#Age Demographics
#Break into Bins of 4 Years
Bins_1 = [0, 9, 14, 19, 24, 29, 34, 39, 100]
bins_Names = ["<10", "10-14", "15-19", "20-24", "25-29",
             "30-34", "35-39", "40+"]
bins_Names
# Out:
# ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

# %%
pd.cut(file_1_DF["Age"], Bins_1, labels = bins_Names).head()
# Out:
# 0    35-39
# 1    20-24
# 2    30-34
# 3    20-24
# 4    20-24
# Name: Age, dtype: category
# Categories (8, object): [<10 < 10-14 < 15-19 < 20-24 < 25-29 < 30-34 < 35-39 < 40+]

# %%
file_1_DF["Age Demographics"] = pd.cut(file_1_DF["Age"], Bins_1, labels = bins_Names)
file_1_DF.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN Age Demographics
# 0     Aelalis34            35-39
# 1        Eolo46            20-24
# 2   Assastnya25            30-34
# 3  Pheusrical25            20-24
# 4        Aela59            20-24

# %%
#Groupby demographics
demoGroup = file_1_DF.groupby(["SN","Age Demographics"])
#How many rows per bin
demoGroup["Age Demographics"].count()
round(demoGroup["Price"].mean(), 2)
AgeDemographics = pd.DataFrame(demoGroup["Age Demographics"].count())
print(AgeDemographics)
# Out:
#                                   Age Demographics
# SN              Age Demographics
# Adairialis76    20-24                            1
# Aduephos78      35-39                            3
# Aeduera68       25-29                            3
# Aela49          25-29                            1
# Aela59          20-24                            1
# Aelalis34       35-39                            2
# Aelin32         20-24                            1
# Aeliriam77      20-24                            2
# Aeliriarin93    20-24                            1
# Aeliru63        20-24                            2
# Aellyria80      25-29                            1
# Aellyrialis39   30-34                            1
# Aellysup38      25-29                            1
# Aelollo59       25-29                            1
# Aenarap34       20-24                            1
# Aenasu69        20-24                            1
# Aeral43         15-19                            1
# ...

# %%
#Average Purchase Price of each column within GroupBy
ageData = file_1_DF.groupby(["Age Demographics"])
ageAvgPp = round(ageData["Price"].mean(),2)
ageAvgPp
# Out:
# Age Demographics
# <10      2.98
# 10-14    2.77
# 15-19    2.91
# 20-24    2.91
# 25-29    2.96
# 30-34    3.08
# 35-39    2.84
# 40+      3.16
# Name: Price, dtype: float64

# %%
ageData = file_1_DF.groupby(["Age Demographics"])
ageSum = file_1_DF.groupby(["SN", "Age Demographics"])
ageSum["SN"].unique()
ageSm= ageSum["SN"].count()
ageSm
# Out:
# SN               Age Demographics
# Adairialis76     20-24               1
# Aduephos78       35-39               3
# Aeduera68        25-29               3
# Aela49           25-29               1
# Aela59           20-24               1
# Aelalis34        35-39               2
# Aelin32          20-24               1
# Aeliriam77       20-24               2
# Aeliriarin93     20-24               1
# Aeliru63         20-24               2
# Aellyria80       25-29               1
# Aellyrialis39    30-34               1
# Aellysup38       25-29               1
# Aelollo59        25-29               1
# Aenarap34        20-24               1
# Aenasu69         20-24               1
# Aeral43          15-19               1
# Aeral85          25-29               1
# Aeral97          10-14               1
# Aeri84           15-19               2
# Aerillorin70     25-29               1
# Aerithllora36    25-29               3
# Aerithnucal56    15-19               2
# ...

# %%
#Purchase Count
ageData = file_1_DF.groupby(["Age Demographics"])
ageCount = ageData["Price"].count()
ageCount
# Out:
# Age Demographics
# <10       28
# 10-14     35
# 15-19    133
# 20-24    336
# 25-29    125
# 30-34     64
# 35-39     42
# 40+       17
# Name: Price, dtype: int64

# %%
#Total Purchase Value
ageTotalPV =ageData["Price"].sum()
ageTotalPV
# Out:
# Age Demographics
# <10       83.46
# 10-14     96.95
# 15-19    386.42
# 20-24    978.77
# 25-29    370.33
# 30-34    197.25
# 35-39    119.40
# 40+       53.75
# Name: Price, dtype: float64

# %%
#Age Bins Normalized Totals
#normalized total:
#total purchase value/number of people per assigned bin
ageNormTotals = round(ageTotalPV / ageCount, 2)
ageNormTotals.head()
# Out:
# Age Demographics
# <10      2.98
# 10-14    2.77
# 15-19    2.91
# 20-24    2.91
# 25-29    2.96
# Name: Price, dtype: float64

# %%
demographic = len(demoGroup["SN"])
demographic.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-712-e027523cb7b3> in <module>()
#       1 demographic = len(demoGroup["SN"])
# ----> 2 demographic.head()
#
# AttributeError: 'int' object has no attribute 'head'

# %%
ageAnalysis= pd.DataFrame({"Purchase Count": ageCount,
                          "Average Purchase Price": ageAvgPp,
                          "Total Purchase Value": ageTotalPV,
                          "Normalized Total": ageNormTotals})
ageAnalysis
# Out:
#                   Average Purchase Price  Normalized Total  Purchase Count  \
# Age Demographics
# <10                                 2.98              2.98              28
# 10-14                               2.77              2.77              35
# 15-19                               2.91              2.91             133
# 20-24                               2.91              2.91             336
# 25-29                               2.96              2.96             125
# 30-34                               3.08              3.08              64
# 35-39                               2.84              2.84              42
# 40+                                 3.16              3.16              17
#
#                   Total Purchase Value
# Age Demographics
# <10                              83.46
# 10-14                            96.95
# 15-19                           386.42
# 20-24                           978.77
# 25-29                           370.33
# ...

# %%
file_1_DF.drop(["Age", "Gender", "Item ID", "Item Name", "Age Demographics"], axis=1)
# Out:
#      Price               SN
# 0     3.37        Aelalis34
# 1     2.32           Eolo46
# 2     2.46      Assastnya25
# 3     1.36     Pheusrical25
# 4     1.27           Aela59
# 5     1.73       Tanimnya91
# 6     4.57      Undjaskla97
# 7     3.32     Iathenudil29
# 8     2.77     Sondenasta63
# 9     4.53       Hilaerin92
# 10    3.81       Chamosia29
# 11    1.55          Sally64
# 12    4.06        Iskossa88
# 13    3.68  Seorithstilis90
# 14    2.46        Sundast29
# 15    4.77       Haellysu29
# 16    1.14       Sundista85
# 17    1.65        Aenarap34
# 18    3.71        Iskista88
# 19    4.89        Assossa43
# 20    2.33          Irith83
# 21    1.79      Iaralrgue74
# 22    2.52         Deural48
# 23    2.36       Chanosia65
# 24    1.96         Qarwen67
# 25    1.27           Idai61
# 26    3.90    Aerithllora36
# 27    2.29      Assastnya25
# 28    4.23      Ilariarin45
# 29    2.46        Phaedai25
# ..     ...              ...
# 750   1.28         Eollym91
# ...

# %%
#Top Spenders by:
#SN
#Total Purchase Value
topSp = file_1_DF.groupby(["SN"]).sum()
topSp.drop(topSp.columns[[0,1]], axis=1, inplace=True)
topSp.rename(columns={"Price": "Total Purchase Value"}, inplace=True)
topSp.sort_values("Total Purchase Value", ascending=False)
print(topSp.nlargest(5, "Total Purchase Value"))


#Purchase Count
purchaseCount= file_1_DF.groupby("SN")["Price"].agg(["sum","count"])
topPC = purchaseCount.sort_values("sum", ascending= False)
print(topPC.nlargest(5, "sum").head())
# file_1_DF[file_1_DF.duplicated(keep=False)]
# topPC = file_1_DF
#Average Purchase Price
topApp = topPC["sum"].div(topPC["count"])
# topApp.drop(topApp.tail(568).index,inplace=True)
round(topApp.iloc[0:5], 2)


# topPC.drop(topPC.tail(568).index,inplace=True)
# topApp = file_1_DF.groupby("SN").agg(np.mean)
# # topApp = file_1_DF[(file_1_DF["SN"].count() >= 4)
# topApp["Price"]
# topApp.rename(columns={"Price": "Total Average Per Price"}, inplace=True)
# # topApp = topPC[(topPC["Price"] >= 4)]
# topApp.sort_values("Total Average Per Price", ascending=False)
# Out:
#              Total Purchase Value
# SN
# Undirrala66                 17.06
# Saedue76                    13.56
# Mindimnya67                 12.74
# Haellysu29                  12.73
# Eoda93                      11.58
#                sum  count
# SN
# Undirrala66  17.06      5
# Saedue76     13.56      4
# Mindimnya67  12.74      4
# Haellysu29   12.73      3
# Eoda93       11.58      3
# SN
# Undirrala66    3.41
# Saedue76       3.39
# Mindimnya67    3.18
# Haellysu29     4.24
# Eoda93         3.86
# dtype: float64

# %%
topPC.drop(topPC.columns[0], axis=1, inplace=True)
Spenders = pd.concat([topSp, topPC], axis=1)
Spenders.index.names=["SN"]
Spenders.rename(columns={"Price": "Total Purchase Value", "count": "Purchase Count"}, inplace=True)
Spenders.sort_values("Total Purchase Value", ascending=False)
Spenders.nlargest(5, "Total Purchase Value")
topSpenders = pd.concat([round(topApp, 2), Spenders], axis=1)
topSpenders.nlargest(5, "Total Purchase Value")
# Out:
#                 0  Total Purchase Value  Purchase Count
# Undirrala66  3.41                 17.06               5
# Saedue76     3.39                 13.56               4
# Mindimnya67  3.18                 12.74               4
# Haellysu29   4.24                 12.73               3
# Eoda93       3.86                 11.58               3

# %%
# Purchase Count
# mpiPC= pd.DataFrame(file_1_DF.groupby(["Item ID", "Item Name"]).count()["Price"])
# mpiPC_1= mpiPC.nlargest(5, "Price")
# mpiPC_1.rename(columns={"Price": "Purchase Count"}, inplace=True)
# mpiPC_1
mpiPC= file_1_DF.groupby(["Item ID","Item Name"]).count()
mpiPC.drop(mpiPC.columns[[0,1,2,4]], axis=1, inplace=True)
mpiPC.sort_values("SN", ascending=False)
mpiPC.rename(columns={"SN": "Purchase Count"}, inplace=True)
mpiPC.sort_values("Purchase Count", ascending=False)

# purchaseCount= file_1_DF.groupby("SN")["Price"].agg(["sum","count"])
# topPC = purchaseCount.sort_values("sum", ascending= False)
# print(topPC.nlargest(5, "sum"))
# Out:
#                                                       Purchase Count
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows                      11
# 84      Arcane Gem                                                11
# 31      Trickster                                                  9
# 175     Woeful Adamantite Claymore                                 9
# 13      Serenity                                                   9
# 34      Retribution Axe                                            9
# 65      Conqueror Adamantite Mace                                  8
# 152     Darkheart                                                  8
# 44      Bonecarvin Battle Axe                                      8
# 107     Splitter, Foe Of Subtlety                                  8
# 106     Crying Steel Sickle                                        8
# 92      Final Critic                                               8
# ...

# %%
# Total Purchase Value
mpiPrice.equals(mpiPC)
mpiTotal= pd.concat([mpiPrice, mpiPC], axis=1)
mpiTotal.rename(columns={"Price": "Total Purchase Value"}, inplace=True)
mpiTotal.sort_values("Purchase Count", ascending=False).head()
# mpiPrice= file_1_DF.groupby("Item ID")["Item name"].agg(["sum","count"]
# pd.DataFrame(file_1_DF.groupby(["Item ID", "Item Name"], sort=False).max())
# # mpiPrice.drop(mpiPrice.columns[[0]], axis=1, inplace=True)
# if mpiPrice[""]
# Out:
#                                               Total Purchase Value  \
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows                 25.85
# 84      Arcane Gem                                           24.53
# 31      Trickster                                            18.63
# 175     Woeful Adamantite Claymore                           11.16
# 13      Serenity                                             13.41
#
#                                               Purchase Count
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows              11
# 84      Arcane Gem                                        11
# 31      Trickster                                          9
# 175     Woeful Adamantite Claymore                         9
# 13      Serenity                                           9

# %%
mpiItemPrice= mpiTotal["Total Purchase Value"].div(mpiTotal["Purchase Count"])
mpiItemPrice.rename(columns={0: "Price"}, inplace=True)
mpiItemPrice
mostPopularTable=pd.concat([mpiItemPrice, mpiTotal], axis=1)
mostPopularTable.rename(columns={"0": "Item Price"}, inplace=True)
mostPopularTable.sort_values("Purchase Count", ascending=False).head()
# Out:
#                                                  0  Total Purchase Value  \
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows  2.35                 25.85
# 84      Arcane Gem                            2.23                 24.53
# 31      Trickster                             2.07                 18.63
# 175     Woeful Adamantite Claymore            1.24                 11.16
# 13      Serenity                              1.49                 13.41
#
#                                               Purchase Count
# Item ID Item Name
# 39      Betrayal, Whisper of Grieving Widows              11
# 84      Arcane Gem                                        11
# 31      Trickster                                          9
# 175     Woeful Adamantite Claymore                         9
# 13      Serenity                                           9

# %%
# Most Profitable Items
mostProfit= file_1_DF.groupby(["Item ID","Item Name"]).sum()
mostProfit.drop(mostProfit.columns[0], axis=1, inplace=True)
mostProfit.rename(columns={"Price": "Total Purchase Value"}, inplace=True )
mostProfit.sort_values("Total Purchase Value", ascending=False)
mostProfit.nlargest(5, "Total Purchase Value")
# Out:
#                                     Total Purchase Value
# Item ID Item Name
# 34      Retribution Axe                            37.26
# 115     Spectral Diamond Doomblade                 29.75
# 32      Orenmir                                    29.70
# 103     Singed Scalpel                             29.22
# 107     Splitter, Foe Of Subtlety                  28.88

# %%
mostPurchaseCount= file_1_DF.groupby(["Item ID","Item Name"]).count()
mostPurchaseCount.drop("Age", axis=1, inplace=True)
mostPurchaseCount.drop("Gender", axis=1, inplace=True)
mostPurchaseCount.drop("SN", axis=1, inplace=True)
mostPurchaseCount.drop("Age Demographics", axis=1, inplace=True)
mostPurchaseCount.rename(columns={"Price": "Purchase Count"}, inplace=True )
PurchaseCountMP= pd.concat([mostPurchaseCount, mostProfit], axis=1)
PurchaseCountMP.sort_values("Total Purchase Value", ascending=False)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 34      Retribution Axe                                            9
# 115     Spectral Diamond Doomblade                                 7
# 32      Orenmir                                                    6
# 103     Singed Scalpel                                             6
# 107     Splitter, Foe Of Subtlety                                  8
# 101     Final Critic                                               6
# 7       Thorn, Satchel of Dark Souls                               6
# 145     Fiery Glass Crusader                                       6
# 39      Betrayal, Whisper of Grieving Widows                      11
# 152     Darkheart                                                  8
# 102     Avenger                                                    6
# 158     Darkheart, Butcher of the Champion                         7
# ...

# %%
itemPriceMostProfit= PurchaseCountMP["Total Purchase Value"].div(PurchaseCountMP["Purchase Count"])
itemPriceMostProfit.rename(columns={0: "Price"}, inplace=True)
mostProfitItemPriced= pd.concat([itemPriceMostProfit, PurchaseCountMP], axis=1)
mostProfitItemPriced.sort_values("Total Purchase Value", ascending=False)
mostProfitItemPriced.nlargest(5, "Total Purchase Value")
# Out:
#                                        0  Purchase Count  Total Purchase Value
# Item ID Item Name
# 34      Retribution Axe             4.14               9                 37.26
# 115     Spectral Diamond Doomblade  4.25               7                 29.75
# 32      Orenmir                     4.95               6                 29.70
# 103     Singed Scalpel              4.87               6                 29.22
# 107     Splitter, Foe Of Subtlety   3.61               8                 28.88

# %%
# merge_DF = file_1_DF.merge(file_2_DF, how= "left")
# merge_DF.head()

# %%
# merged_data = pd.DataFrame(merge_DF)
# merged_data.head()
