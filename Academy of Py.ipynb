# %%
#Depenencies
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
#call csv file on schools
#create DataFrame
#use .head() to check
csv_pathSchools ="Resources/schools_complete.csv"
raw_data_schoolsDF = pd.read_csv(csv_pathSchools)
raw_data_schoolsDF.head()
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
raw_data_schoolsDF.columns
# Out:
# Index(['School ID', 'name', 'type', 'size', 'budget'], dtype='object')

# %%
#insert Field Name Schools for schools file
schoolsDF = raw_data_schoolsDF.rename(columns={"name": "school"})
schoolsDF.dtypes
# Out:
# School ID     int64
# school       object
# type         object
# size          int64
# budget        int64
# dtype: object

# %%
schoolsNumeric = schoolsDFR({})
schoolsNumeric
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# Name: school, dtype: float64

# %%
#call csv file on students
#create DataFrame
#use .head() to check
csv_pathStudents = "Resources/students_complete.csv"
raw_data_studentsDF = pd.read_csv(csv_pathStudents)
raw_data_studentsDF
# Out:
#        Student ID                 name gender grade              school  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
#merge both files
merge_table = schoolsDF.merge(raw_data_studentsDF, how="inner")
merge_table.describe()
# Out:
#           School ID          size        budget    Student ID  reading_score  \
# count  39170.000000  39170.000000  3.917000e+04  39170.000000    39170.00000
# mean       6.978172   3332.957110  2.117241e+06  19584.500000       81.87784
# std        4.444329   1323.914069  8.749987e+05  11307.549359       10.23958
# min        0.000000    427.000000  2.480870e+05      0.000000       63.00000
# 25%        3.000000   1858.000000  1.081356e+06   9792.250000       73.00000
# 50%        7.000000   2949.000000  1.910635e+06  19584.500000       82.00000
# 75%       11.000000   4635.000000  3.022020e+06  29376.750000       91.00000
# max       14.000000   4976.000000  3.124928e+06  39169.000000       99.00000
#
#          math_score
# count  39170.000000
# mean      78.985371
# std       12.309968
# min       55.000000
# 25%       69.000000
# 50%       79.000000
# 75%       89.000000
# max       99.000000

# %%
#Remove missing data
merge_table
# Out:
#        School ID              school      type  size   budget  Student ID  \
# 0              0   Huang High School  District  2917  1910635           0
# 1              0   Huang High School  District  2917  1910635           1
# 2              0   Huang High School  District  2917  1910635           2
# 3              0   Huang High School  District  2917  1910635           3
# 4              0   Huang High School  District  2917  1910635           4
# 5              0   Huang High School  District  2917  1910635           5
# 6              0   Huang High School  District  2917  1910635           6
# 7              0   Huang High School  District  2917  1910635           7
# 8              0   Huang High School  District  2917  1910635           8
# 9              0   Huang High School  District  2917  1910635           9
# 10             0   Huang High School  District  2917  1910635          10
# 11             0   Huang High School  District  2917  1910635          11
# ...

# %%
school_table= merge_table.loc[merge_table["school"] == 
"Bailey High School",
"Johnson High School",
"Hernandez High School",
"Rodriguez High School",
"Figueroa High School",
"Huang High School",
"Ford High School",
"Wilson High School",
"Cabrera High School",
"Wright High School",
"Shelton High School",
"Thomas High School",  
"Griffin High School", 
"Pena High School",
"Holden High School"
:]
school_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [Johnson High School] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-d655bcd8742a> in <module>()
#      14 "Griffin High School",
#      15 "Pena High School",
# ---> 16 "Holden High School"
#      17 :]
# ...

# %%
#display key metrics of district
 = merge_table({"school" : ["Huang High School"]})
unique_table.groupby(["school"]).sum()
#Total Schools
#Total Students
#Total Budget
#Average Math Score
#Average Reading Score
#% Passing Math
#% Passing Reading
#Overall Passing Rate (Average of the above two)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-6628b7ecb57e> in <module>()
#       1 #display key metrics of district
# ----> 2 unique_table = merge_table({"school" : ["Huang High School"]})
#       3 unique_table.groupby(["school"]).sum()
#       4 #Total Schools
#       5 #Total Students
#
# TypeError: 'DataFrame' object is not callable

# %%
#display key metrics of school
#School Name
#School Type
#Total Students
#Total School Budget
#Per Student Budget
#Average Math Score
#Average Reading Score
#% Passing Math
#% Passing Reading
#Overall Passing Rate (Average of the above two)

# %%
#sort top schools by passing rate
#Table that shows:
#School Name
#School Type
#Total Students
#Total School Budget
#Per Student Budget
#Average Math Score
#Average Reading Score
#% Passing Math
#% Passing Reading
#Overall Passing Rate (Average of the above two)

# %%
#table of bottom 5 schools by passing rate
#same metrics as top schools

# %%
#AVERAGE math scores per grade level (9-12)
#By school

# %%
#AVERAGE reading scores per grade level (9-12)
#By school

# %%
#Table scores by average school spending
#Range is per student
#Create 4 reasonable bings
#Average Math Score
#Average Reading Score
#% Passing Math
#% Passing Reading
#Overall Passing Rate (Average of the above two)

# %%
#Scores by School size
#Bings represent small, mid, large
#Same metrics as above

# %%
#Charter score v. District scores
#same metrics as above
